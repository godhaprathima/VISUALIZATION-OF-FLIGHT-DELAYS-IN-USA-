# %%
# read data of flight.csv

import pandas as pd
path = 'flights.csv'
flight_data = pd.read_csv(path, dtype={'ORIGIN_AIRPORT': str, 
                                               'DESTINATION_AIRPORT': str})

# %%
airlines=pd.read_csv('airlines.csv')
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
flight_data.shape
# Out:
# (5819079, 31)

# %%
flight_data.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                  NaN               NaN
# 1           -9.0         0          0                  NaN               NaN
# 2            5.0         0          0                  NaN               NaN
# 3           -9.0         0          0                  NaN               NaN
# 4          -21.0         0          0                  NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
# [5 rows x 31 columns]

# %%
flight_data[flight_data.columns[0]].unique()
# Out:
# array([2015])

# %%
#Different columns of data

flight_data.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
flight_data[flight_data.columns[24]].unique()
# Out:
# array([0, 1])

# %% [markdown]
# # <font size=10>Visualization 1</font>

# %%
#Drop NAN rows of Arrival delay and departure delay

flights_data=flight_data.dropna(axis=0, subset=['ARRIVAL_DELAY', 'DEPARTURE_DELAY'])

# %%
#Taking only the necessary columns from the flights data 

flights=flights_data.loc[:,['MONTH','DAY','DAY_OF_WEEK','AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT',
                           'DEPARTURE_DELAY','DISTANCE','ARRIVAL_DELAY','DIVERTED' ,'AIR_SYSTEM_DELAY','SECURITY_DELAY',
                            'AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY']]

# %%
#Mapping airline data and flights data using Airline code column

flights = flights.rename(columns={'AIRLINE': 'IATA_CODE'})
flights = flights.merge(airlines, on='IATA_CODE')

# %%
flights.head()
# Out:
#    MONTH  DAY  DAY_OF_WEEK IATA_CODE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0      1    1            4        AS            ANC                 SEA
# 1      1    1            4        AS            SEA                 ANC
# 2      1    1            4        AS            ANC                 SEA
# 3      1    1            4        AS            ANC                 PDX
# 4      1    1            4        AS            FAI                 SEA
#
#    DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY  DIVERTED  AIR_SYSTEM_DELAY  \
# 0            -11.0      1448          -22.0         0               NaN
# 1             -1.0      1448          -21.0         0               NaN
# 2             -4.0      1448          -14.0         0               NaN
# 3             -4.0      1542          -18.0         0               NaN
# 4             -8.0      1533           -3.0         0               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#                 AIRLINE
# 0  Alaska Airlines Inc.
# 1  Alaska Airlines Inc.
# 2  Alaska Airlines Inc.
# 3  Alaska Airlines Inc.
# 4  Alaska Airlines Inc.

# %%
#calculating the fraction or mean arrival and departure delays of different airlines

airline_delay_data=flights.loc[:, ['AIRLINE','DEPARTURE_DELAY','ARRIVAL_DELAY']].groupby('AIRLINE').mean()

# %%
airline_delay_data
# Out:
#                               DEPARTURE_DELAY  ARRIVAL_DELAY
# AIRLINE
# Alaska Airlines Inc.                 1.718926      -0.976563
# American Airlines Inc.               8.826106       3.451372
# American Eagle Airlines Inc.         9.967187       6.457873
# Atlantic Southeast Airlines          8.615598       6.585379
# Delta Air Lines Inc.                 7.313300       0.186754
# Frontier Airlines Inc.              13.303352      12.504706
# Hawaiian Airlines Inc.               0.469918       2.023093
# JetBlue Airways                     11.442467       6.677861
# Skywest Airlines Inc.                7.736083       5.845652
# Southwest Airlines Co.              10.517183       4.374964
# Spirit Air Lines                    15.883101      14.471800
# US Airways Inc.                      6.081000       3.706209
# United Air Lines Inc.               14.333056       5.431594
# Virgin America                       8.993486       4.737706

# %%
#Plotting stacked arrival and departure delay bar plot

import matplotlib.pyplot as plt 

ax=airline_delay_data.plot(kind='barh',figsize=(10,10),title='Average Departure and Arrival delay times for different Airlines',ylabel='Time in minutes')
for container in ax.containers:
    ax.bar_label(container)

# %%
airline=flights.loc[:,'AIRLINE'].unique()

# %% [markdown]
# # <font size=10>Visualization 2</font>

# %%
airline
# Out:
# array(['Alaska Airlines Inc.', 'American Airlines Inc.',
#        'US Airways Inc.', 'Delta Air Lines Inc.', 'Spirit Air Lines',
#        'United Air Lines Inc.', 'Hawaiian Airlines Inc.',
#        'JetBlue Airways', 'Skywest Airlines Inc.',
#        'Atlantic Southeast Airlines', 'Frontier Airlines Inc.',
#        'Southwest Airlines Co.', 'American Eagle Airlines Inc.',
#        'Virgin America'], dtype=object)

# %%
monthly_delays=pd.DataFrame()

# %%
#Computing the monthly average delay time of differerent airlines 

for services in airline:
    #print(services)
    airline_delay=flights[flights['AIRLINE']==services] 
    airline_month_delays=airline_delay.loc[:, ['MONTH','ARRIVAL_DELAY']].groupby('MONTH').mean()
    monthly_delays[services]=airline_month_delays

# %%
monthly_delays=monthly_delays.fillna(0)
monthly_delays
# Out:
#        Alaska Airlines Inc.  American Airlines Inc.  US Airways Inc.  \
# MONTH
# 1                 -0.320888                6.955843         3.107457
# 2                 -0.782923                7.530204         7.114455
# 3                 -0.544731                6.693587         3.330787
# 4                 -3.009003                4.931778         2.660290
# 5                 -1.716398                5.173878         0.681605
# 6                 -0.220621                8.191017         5.766296
# 7                  0.377408                3.870440         0.000000
# 8                  2.503899                3.193907         0.000000
# 9                 -1.813800               -1.432732         0.000000
# 10                -2.993617               -0.580930         0.000000
# 11                -1.916516                0.772630         0.000000
# 12                -1.846681                4.149684         0.000000
#
#        Delta Air Lines Inc.  Spirit Air Lines  United Air Lines Inc.  \
# MONTH
# 1                 -2.043847         11.398054               6.352729
# 2                  5.614745         16.474466               7.260662
# 3                  2.077965         10.039118               4.892212
# 4                  0.083343          8.766224               4.376092
# 5                  0.149333         22.397347               6.827695
# 6                  4.419594         35.561501              16.932663
# 7                  1.204862         14.352382              10.262551
# 8                  0.653114         20.519018               5.014041
# 9                 -3.703377          8.000101              -1.794265
# 10                -5.011516          6.810736              -2.456542
# 11                -3.175414          7.543881               0.281064
# 12                 2.504595         12.733123               7.012079
#
#        Hawaiian Airlines Inc.  JetBlue Airways  Skywest Airlines Inc.  \
# MONTH
# 1                    3.512640         7.347281              10.889894
# 2                    6.029967        18.657673               9.588895
# 3                    3.468383        10.741317               3.181693
# 4                    0.011022         2.780105               3.223796
# 5                    0.826426        -0.709019               4.141162
# 6                    0.882786         5.047155               8.338477
# 7                    2.001586         5.841454               6.790333
# 8                    7.448029         9.280950               5.606689
# 9                    3.696915         3.539154               1.530896
# 10                   0.467074         3.676787               1.750897
# 11                  -2.719894         1.418299               4.925548
# 12                  -1.706475        13.839290              10.947612
#
#        Atlantic Southeast Airlines  Frontier Airlines Inc.  \
# MONTH
# 1                         8.537497               18.357238
# 2                        10.417236               27.424179
# 3                         6.730101               20.074855
# 4                         4.821253               12.640440
# 5                         7.724290               13.007554
# 6                        13.952793               19.712951
# 7                         6.926421               14.464543
# 8                         5.154422                9.175737
# 9                         0.851062                0.978460
# 10                        2.303760                0.082127
# 11                        4.415930               11.164527
# 12                        6.685176                9.346221
#
#        Southwest Airlines Co.  American Eagle Airlines Inc.  Virgin America
# MONTH
# 1                    3.389466                     18.164974        1.420702
# 2                    3.501363                     21.301627        7.784410
# 3                    3.263341                     11.018418        5.348207
# 4                    2.996399                      5.131228        0.995507
# 5                    5.680777                      5.466790        7.102021
# 6                   10.743462                      9.639323        5.779415
# 7                   10.504942                      3.980289        7.135773
# 8                    5.532108                      1.896565        5.106221
# 9                   -1.336260                     -2.167268        0.070998
# 10                  -0.688851                     -3.735054        2.254278
# 11                   0.995684                      0.220061        0.116370
# 12                   6.720893                      0.662486       13.498720

# %%
monthly_delays.loc[6,:]
# Out:
# Alaska Airlines Inc.            -0.220621
# American Airlines Inc.           8.191017
# US Airways Inc.                  5.766296
# Delta Air Lines Inc.             4.419594
# Spirit Air Lines                35.561501
# United Air Lines Inc.           16.932663
# Hawaiian Airlines Inc.           0.882786
# JetBlue Airways                  5.047155
# Skywest Airlines Inc.            8.338477
# Atlantic Southeast Airlines     13.952793
# Frontier Airlines Inc.          19.712951
# Southwest Airlines Co.          10.743462
# American Eagle Airlines Inc.     9.639323
# Virgin America                   5.779415
# Name: 6, dtype: float64

# %%
max_values=monthly_delays.loc[6,:].nlargest(3)
min_values=monthly_delays.loc[6,:].nsmallest(3)

# %%
max_airlines=pd.DataFrame()

# %%
#Seperating airlines with maximum average delay time

for i in range(0,len(max_values)):
    for col in monthly_delays.columns:
        #print(monthly_delays.loc[6,col])
        if(monthly_delays.loc[6,col]==max_values[i]):
            max_airlines[col]=monthly_delays[col]
max_airlines
# Out:
#        Spirit Air Lines  Frontier Airlines Inc.  United Air Lines Inc.
# MONTH
# 1             11.398054               18.357238               6.352729
# 2             16.474466               27.424179               7.260662
# 3             10.039118               20.074855               4.892212
# 4              8.766224               12.640440               4.376092
# 5             22.397347               13.007554               6.827695
# 6             35.561501               19.712951              16.932663
# 7             14.352382               14.464543              10.262551
# 8             20.519018                9.175737               5.014041
# 9              8.000101                0.978460              -1.794265
# 10             6.810736                0.082127              -2.456542
# 11             7.543881               11.164527               0.281064
# 12            12.733123                9.346221               7.012079

# %%
min_airlines=pd.DataFrame()

# %%
#Seperating airlines with minimum average delay time

for i in range(0,len(min_values)):
    for col in monthly_delays.columns:
        #print(monthly_delays.loc[6,col])
        if(monthly_delays.loc[6,col]==min_values[i]):
            min_airlines[col]=monthly_delays[col]
min_airlines
# Out:
#        Alaska Airlines Inc.  Hawaiian Airlines Inc.  Delta Air Lines Inc.
# MONTH
# 1                 -0.320888                3.512640             -2.043847
# 2                 -0.782923                6.029967              5.614745
# 3                 -0.544731                3.468383              2.077965
# 4                 -3.009003                0.011022              0.083343
# 5                 -1.716398                0.826426              0.149333
# 6                 -0.220621                0.882786              4.419594
# 7                  0.377408                2.001586              1.204862
# 8                  2.503899                7.448029              0.653114
# 9                 -1.813800                3.696915             -3.703377
# 10                -2.993617                0.467074             -5.011516
# 11                -1.916516               -2.719894             -3.175414
# 12                -1.846681               -1.706475              2.504595

# %%
rem_airlines=pd.DataFrame()

# %%
for col in monthly_delays.columns:
    if col in max_airlines.columns or col in min_airlines.columns:
        print('true')
    else:
        rem_airlines[col]=monthly_delays[col]
rem_airlines
# Out:
# true
# true
# true
# true
# true
# true
#        American Airlines Inc.  US Airways Inc.  JetBlue Airways  \
# MONTH
# 1                    6.955843         3.107457         7.347281
# 2                    7.530204         7.114455        18.657673
# 3                    6.693587         3.330787        10.741317
# 4                    4.931778         2.660290         2.780105
# 5                    5.173878         0.681605        -0.709019
# 6                    8.191017         5.766296         5.047155
# 7                    3.870440         0.000000         5.841454
# 8                    3.193907         0.000000         9.280950
# 9                   -1.432732         0.000000         3.539154
# 10                  -0.580930         0.000000         3.676787
# 11                   0.772630         0.000000         1.418299
# 12                   4.149684         0.000000        13.839290
#
#        Skywest Airlines Inc.  Atlantic Southeast Airlines  \
# MONTH
# 1                  10.889894                     8.537497
# 2                   9.588895                    10.417236
# 3                   3.181693                     6.730101
# 4                   3.223796                     4.821253
# 5                   4.141162                     7.724290
# 6                   8.338477                    13.952793
# 7                   6.790333                     6.926421
# 8                   5.606689                     5.154422
# 9                   1.530896                     0.851062
# 10                  1.750897                     2.303760
# 11                  4.925548                     4.415930
# 12                 10.947612                     6.685176
#
#        Southwest Airlines Co.  American Eagle Airlines Inc.  Virgin America
# MONTH
# 1                    3.389466                     18.164974        1.420702
# 2                    3.501363                     21.301627        7.784410
# 3                    3.263341                     11.018418        5.348207
# 4                    2.996399                      5.131228        0.995507
# 5                    5.680777                      5.466790        7.102021
# 6                   10.743462                      9.639323        5.779415
# 7                   10.504942                      3.980289        7.135773
# 8                    5.532108                      1.896565        5.106221
# 9                   -1.336260                     -2.167268        0.070998
# 10                  -0.688851                     -3.735054        2.254278
# 11                   0.995684                      0.220061        0.116370
# 12                   6.720893                      0.662486       13.498720

# %%
#Plot the line plot of average delay time of all the airline in different months of the year

import plotly.graph_objs as go
import random
from ipywidgets import widgets

f = go.FigureWidget()
f.layout.hovermode = 'closest'
f.layout.hoverdistance = -1 
default_linewidth = 2
highlighted_linewidth_delta = 2

num_of_traces = 5
random.seed = 42
for i in range(0,len(rem_airlines.columns)):
    trace = go.Scatter(y=rem_airlines.iloc[:,i], mode='markers+lines',hoverinfo='name+y', opacity=0.15, line={ 'width': default_linewidth },marker={'symbol':'circle'},name=str(rem_airlines.columns[i]))
    f.add_trace(trace)

for i in range(0,len(max_airlines.columns)):
    trace = go.Scatter(y=max_airlines.iloc[:,i], mode='markers+lines',hoverinfo='name+y', line={ 'width': default_linewidth },marker={'symbol':'circle'},name=str(max_airlines.columns[i]))
    f.add_trace(trace)
    
for i in range(0,len(min_airlines.columns)):
    trace = go.Scatter(y=min_airlines.iloc[:,i], mode='markers+lines',hoverinfo='name+y', line={ 'width': default_linewidth },marker={'symbol':'circle'},name=str(min_airlines.columns[i]))
    f.add_trace(trace)
f.update_layout(
    
    title="Average monthly delay times of different airlines",
    xaxis_title="months",
    yaxis_title="Average delay time",
    width=1000,
    height=700,
)
def update_trace(trace, points, selector):
    if len(points.point_inds) == 0:
        return
        
    for i,_ in enumerate(f.data):
        f.data[i]['line']['width'] = default_linewidth + highlighted_linewidth_delta * (i == points.trace_index)
        f.data[i]['opacity']=1.0*(i == points.trace_index)+ 0.2*(i != points.trace_index)
        
        
for i in range( len(f.data) ):
    f.data[i].on_click(update_trace)

f

# %% [markdown]
# # <font size=10>Visualization 3</font>

# %%
#loading airports locations csv file

airport = pd.read_csv('airports.csv')

# %%
flights['DELAY_OR_NOT'] = flights.loc[:, ['ARRIVAL_DELAY']] > 0

# %%
airport
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
flights
# Out:
#          MONTH  DAY  DAY_OF_WEEK IATA_CODE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0            1    1            4        AS            ANC                 SEA
# 1            1    1            4        AS            SEA                 ANC
# 2            1    1            4        AS            ANC                 SEA
# 3            1    1            4        AS            ANC                 PDX
# 4            1    1            4        AS            FAI                 SEA
# ...        ...  ...          ...       ...            ...                 ...
# 5714003     12   31            4        VX            LGA                 DAL
# 5714004     12   31            4        VX            BOS                 SFO
# 5714005     12   31            4        VX            SFO                 LAS
# 5714006     12   31            4        VX            LAX                 LAS
# 5714007     12   31            4        VX            OGG                 SFO
#
#          DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY  DIVERTED  AIR_SYSTEM_DELAY  \
# 0                  -11.0      1448          -22.0         0               NaN
# 1                   -1.0      1448          -21.0         0               NaN
# 2                   -4.0      1448          -14.0         0               NaN
# 3                   -4.0      1542          -18.0         0               NaN
# 4                   -8.0      1533           -3.0         0               NaN
# ...                  ...       ...            ...       ...               ...
# 5714003             -8.0      1381           -6.0         0               NaN
# 5714004            -10.0      2704          -46.0         0               NaN
# 5714005             -7.0       414          -18.0         0               NaN
# 5714006             -2.0       236          -11.0         0               NaN
# 5714007             -2.0      2338          -37.0         0               NaN
#
#          SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0                   NaN            NaN                  NaN            NaN
# 1                   NaN            NaN                  NaN            NaN
# 2                   NaN            NaN                  NaN            NaN
# 3                   NaN            NaN                  NaN            NaN
# 4                   NaN            NaN                  NaN            NaN
# ...                 ...            ...                  ...            ...
# 5714003             NaN            NaN                  NaN            NaN
# 5714004             NaN            NaN                  NaN            NaN
# 5714005             NaN            NaN                  NaN            NaN
# 5714006             NaN            NaN                  NaN            NaN
# 5714007             NaN            NaN                  NaN            NaN
#
#                       AIRLINE  DELAY_OR_NOT
# 0        Alaska Airlines Inc.         False
# 1        Alaska Airlines Inc.         False
# 2        Alaska Airlines Inc.         False
# 3        Alaska Airlines Inc.         False
# 4        Alaska Airlines Inc.         False
# ...                       ...           ...
# 5714003        Virgin America         False
# 5714004        Virgin America         False
# 5714005        Virgin America         False
# 5714006        Virgin America         False
# 5714007        Virgin America         False
#
# [5714008 rows x 17 columns]

# %%
airport = airport.rename(columns={'IATA_CODE': 'DESTINATION_AIRPORT'})

# %%
#Computing delay times and fraction of delayed flights of different airports of USA

airports_flights_data=flights[flights.ORIGIN_AIRPORT.str.isalpha()]
airport_no_flights=airports_flights_data.loc[:,['DESTINATION_AIRPORT','DELAY_OR_NOT']].groupby('DESTINATION_AIRPORT').count()
airport_no_flights = airport_no_flights.rename(columns={'DELAY_OR_NOT': 'FLIGHTS'})

delayed_flights_data=airports_flights_data[airports_flights_data['DELAY_OR_NOT']==1]
airport_no_delays=delayed_flights_data.loc[:,['DESTINATION_AIRPORT','DELAY_OR_NOT']].groupby('DESTINATION_AIRPORT').count()

airport_no_flights=airport_no_flights.merge(airport_no_delays,on='DESTINATION_AIRPORT')

# %%
airport_no_flights
# Out:
#                      FLIGHTS  DELAY_OR_NOT
# DESTINATION_AIRPORT
# ABE                     2220           840
# ABI                     2224           748
# ABQ                    18953          7876
# ABR                      657           163
# ABY                      864           347
# ...                      ...           ...
# WRG                      652           259
# WYS                      207           119
# XNA                     8986          3920
# YAK                      652           224
# YUM                     1856           677
#
# [322 rows x 2 columns]

# %%
airport_no_flights['fraction of delayed_flights']=airport_no_flights['DELAY_OR_NOT']/airport_no_flights['FLIGHTS']

# %%
airport_no_flights
# Out:
#                      FLIGHTS  DELAY_OR_NOT  fraction of delayed_flights
# DESTINATION_AIRPORT
# ABE                     2220           840                     0.378378
# ABI                     2224           748                     0.336331
# ABQ                    18953          7876                     0.415554
# ABR                      657           163                     0.248097
# ABY                      864           347                     0.401620
# ...                      ...           ...                          ...
# WRG                      652           259                     0.397239
# WYS                      207           119                     0.574879
# XNA                     8986          3920                     0.436234
# YAK                      652           224                     0.343558
# YUM                     1856           677                     0.364763
#
# [322 rows x 3 columns]

# %%
airport_delay_time=delayed_flights_data.loc[:, ['DESTINATION_AIRPORT','ARRIVAL_DELAY']].groupby('DESTINATION_AIRPORT').mean()
airport_delay_time
# Out:
#                      ARRIVAL_DELAY
# DESTINATION_AIRPORT
# ABE                      31.459524
# ABI                      31.830214
# ABQ                      28.017395
# ABR                      24.453988
# ABY                      34.138329
# ...                            ...
# WRG                      32.019305
# WYS                      10.336134
# XNA                      33.655867
# YAK                      23.562500
# YUM                      22.391433
#
# [322 rows x 1 columns]

# %%
#Merging average arrival time and fraction of delayed flights data into airports dataframe

airport = airport.merge(airport_no_flights['fraction of delayed_flights'], on='DESTINATION_AIRPORT')
airport = airport.merge(airport_delay_time['ARRIVAL_DELAY'], on='DESTINATION_AIRPORT')

# %%
airport
# Out:
#     DESTINATION_AIRPORT                              AIRPORT  \
# 0                   ABE  Lehigh Valley International Airport
# 1                   ABI             Abilene Regional Airport
# 2                   ABQ    Albuquerque International Sunport
# 3                   ABR            Aberdeen Regional Airport
# 4                   ABY   Southwest Georgia Regional Airport
# ..                  ...                                  ...
# 317                 WRG                     Wrangell Airport
# 318                 WYS               Westerly State Airport
# 319                 XNA  Northwest Arkansas Regional Airport
# 320                 YAK                      Yakutat Airport
# 321                 YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE  \
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
#      fraction of delayed_flights  ARRIVAL_DELAY
# 0                       0.378378      31.459524
# 1                       0.336331      31.830214
# 2                       0.415554      28.017395
# 3                       0.248097      24.453988
# 4                       0.401620      34.138329
# ..                           ...            ...
# 317                     0.397239      32.019305
# 318                     0.574879      10.336134
# 319                     0.436234      33.655867
# 320                     0.343558      23.562500
# 321                     0.364763      22.391433
#
# [322 rows x 9 columns]

# %%
from statistics import median
flights_median= median(airport.loc[:,'fraction of delayed_flights'])
delaytime_median= median(airport.loc[:,'ARRIVAL_DELAY'])

# %%
#Calculating few statistical parameters to use them in altering the color and size of the marks of each airport.

import numpy as np
flights_25=np.percentile(airport.loc[:,'fraction of delayed_flights'], 25)
flights_75=np.percentile(airport.loc[:,'fraction of delayed_flights'], 75)
time_25=np.percentile(airport.loc[:,'ARRIVAL_DELAY'], 25)
time_75=np.percentile(airport.loc[:,'ARRIVAL_DELAY'], 75)

# %%
from vega_datasets import data

# %%
import altair as alt

#alt.renderers.enable('notebook')
# alt.renderers.enable('jupyterlab')
alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %%
#Loading USA states location data on US map

usmap = data.us_10m()
usmap.keys()
state1 = usmap['objects']['states']['geometries'][1]
state1
states = alt.topo_feature(data.us_10m.url, 'states')

# %%
type(airport['LATITUDE'][0])
# Out:
# numpy.float64

# %%
airlne_airports=airports_flights_data.loc[:,['DESTINATION_AIRPORT','AIRLINE','ARRIVAL_DELAY']].groupby(['DESTINATION_AIRPORT','AIRLINE']).mean()

# %%
airline_airports=airlne_airports.pivot_table('ARRIVAL_DELAY',['DESTINATION_AIRPORT'],'AIRLINE')

# %%
airline_airports
# Out:
# AIRLINE              Alaska Airlines Inc.  American Airlines Inc.  \
# DESTINATION_AIRPORT
# ABE                                   NaN                     NaN
# ABI                                   NaN                     NaN
# ABQ                            -17.389222                4.414607
# ABR                                   NaN                     NaN
# ABY                                   NaN                     NaN
# ...                                   ...                     ...
# WRG                              5.375767                     NaN
# WYS                                   NaN                     NaN
# XNA                                   NaN               -8.055556
# YAK                              0.371166                     NaN
# YUM                                   NaN                     NaN
#
# AIRLINE              American Eagle Airlines Inc.  \
# DESTINATION_AIRPORT
# ABE                                           NaN
# ABI                                      4.081385
# ABQ                                      8.065789
# ABR                                           NaN
# ABY                                           NaN
# ...                                           ...
# WRG                                           NaN
# WYS                                           NaN
# XNA                                     12.202115
# YAK                                           NaN
# YUM                                           NaN
#
# AIRLINE              Atlantic Southeast Airlines  Delta Air Lines Inc.  \
# DESTINATION_AIRPORT
# ABE                                     6.067669              3.990228
# ABI                                          NaN                   NaN
# ABQ                                     2.792593             -0.789006
# ABR                                          NaN                   NaN
# ABY                                     8.681713                   NaN
# ...                                          ...                   ...
# WRG                                          NaN                   NaN
# WYS                                          NaN                   NaN
# XNA                                     6.778879             -0.104089
# YAK                                          NaN                   NaN
# YUM                                          NaN                   NaN
#
# AIRLINE              Frontier Airlines Inc.  Hawaiian Airlines Inc.  \
# DESTINATION_AIRPORT
# ABE                                     NaN                     NaN
# ABI                                     NaN                     NaN
# ABQ                                     NaN                     NaN
# ABR                                     NaN                     NaN
# ABY                                     NaN                     NaN
# ...                                     ...                     ...
# WRG                                     NaN                     NaN
# WYS                                     NaN                     NaN
# XNA                                     NaN                     NaN
# YAK                                     NaN                     NaN
# YUM                                     NaN                     NaN
#
# AIRLINE              JetBlue Airways  Skywest Airlines Inc.  \
# DESTINATION_AIRPORT
# ABE                              NaN               6.882353
# ABI                              NaN                    NaN
# ABQ                         4.483395               5.499386
# ABR                              NaN              -3.389650
# ABY                              NaN                    NaN
# ...                              ...                    ...
# WRG                              NaN                    NaN
# WYS                              NaN               4.193237
# XNA                              NaN               5.822258
# YAK                              NaN                    NaN
# YUM                              NaN               3.259159
#
# AIRLINE              Southwest Airlines Co.  Spirit Air Lines  \
# DESTINATION_AIRPORT
# ABE                                     NaN               NaN
# ABI                                     NaN               NaN
# ABQ                                7.204917               NaN
# ABR                                     NaN               NaN
# ABY                                     NaN               NaN
# ...                                     ...               ...
# WRG                                     NaN               NaN
# WYS                                     NaN               NaN
# XNA                                     NaN               NaN
# YAK                                     NaN               NaN
# YUM                                     NaN               NaN
#
# AIRLINE              US Airways Inc.  United Air Lines Inc.  Virgin America
# DESTINATION_AIRPORT
# ABE                              NaN                    NaN             NaN
# ABI                              NaN                    NaN             NaN
# ABQ                         9.428571                9.02924             NaN
# ABR                              NaN                    NaN             NaN
# ABY                              NaN                    NaN             NaN
# ...                              ...                    ...             ...
# WRG                              NaN                    NaN             NaN
# WYS                              NaN                    NaN             NaN
# XNA                              NaN                    NaN             NaN
# YAK                              NaN                    NaN             NaN
# YUM                              NaN                    NaN             NaN
#
# [322 rows x 14 columns]

# %%
min_delay_time = airline_airports.min(axis = 1)
mindelay_airline=airline_airports.idxmin(axis = 1)
max_delay_time = airline_airports.max(axis = 1)
max_delay_airline = airline_airports.idxmax(axis = 1)

# %%
delays=pd.DataFrame()
delays['min_delay_time']=min_delay_time
delays['mindelay_airline']=mindelay_airline
delays['max_delay_time']=max_delay_time
delays['max_delay_airline']=max_delay_airline

# %%
delays
# Out:
#                      min_delay_time              mindelay_airline  \
# DESTINATION_AIRPORT
# ABE                        3.990228          Delta Air Lines Inc.
# ABI                        4.081385  American Eagle Airlines Inc.
# ABQ                      -17.389222          Alaska Airlines Inc.
# ABR                       -3.389650         Skywest Airlines Inc.
# ABY                        8.681713   Atlantic Southeast Airlines
# ...                             ...                           ...
# WRG                        5.375767          Alaska Airlines Inc.
# WYS                        4.193237         Skywest Airlines Inc.
# XNA                       -8.055556        American Airlines Inc.
# YAK                        0.371166          Alaska Airlines Inc.
# YUM                        3.259159         Skywest Airlines Inc.
#
#                      max_delay_time             max_delay_airline
# DESTINATION_AIRPORT
# ABE                        6.882353         Skywest Airlines Inc.
# ABI                        4.081385  American Eagle Airlines Inc.
# ABQ                        9.428571               US Airways Inc.
# ABR                       -3.389650         Skywest Airlines Inc.
# ABY                        8.681713   Atlantic Southeast Airlines
# ...                             ...                           ...
# WRG                        5.375767          Alaska Airlines Inc.
# WYS                        4.193237         Skywest Airlines Inc.
# XNA                       12.202115  American Eagle Airlines Inc.
# YAK                        0.371166          Alaska Airlines Inc.
# YUM                        3.259159         Skywest Airlines Inc.
#
# [322 rows x 4 columns]

# %%
airport=airport.merge(delays, on='DESTINATION_AIRPORT')

# %%
airport=airport.rename(columns={'ARRIVAL_DELAY': 'Average delay time'})

# %%
airport
# Out:
#     DESTINATION_AIRPORT                              AIRPORT  \
# 0                   ABE  Lehigh Valley International Airport
# 1                   ABI             Abilene Regional Airport
# 2                   ABQ    Albuquerque International Sunport
# 3                   ABR            Aberdeen Regional Airport
# 4                   ABY   Southwest Georgia Regional Airport
# ..                  ...                                  ...
# 317                 WRG                     Wrangell Airport
# 318                 WYS               Westerly State Airport
# 319                 XNA  Northwest Arkansas Regional Airport
# 320                 YAK                      Yakutat Airport
# 321                 YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE  \
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
#      fraction of delayed_flights  Average delay time  min_delay_time  \
# 0                       0.378378           31.459524        3.990228
# 1                       0.336331           31.830214        4.081385
# 2                       0.415554           28.017395      -17.389222
# 3                       0.248097           24.453988       -3.389650
# 4                       0.401620           34.138329        8.681713
# ..                           ...                 ...             ...
# 317                     0.397239           32.019305        5.375767
# 318                     0.574879           10.336134        4.193237
# 319                     0.436234           33.655867       -8.055556
# 320                     0.343558           23.562500        0.371166
# 321                     0.364763           22.391433        3.259159
#
#                  mindelay_airline  max_delay_time  \
# 0            Delta Air Lines Inc.        6.882353
# 1    American Eagle Airlines Inc.        4.081385
# 2            Alaska Airlines Inc.        9.428571
# 3           Skywest Airlines Inc.       -3.389650
# 4     Atlantic Southeast Airlines        8.681713
# ..                            ...             ...
# 317          Alaska Airlines Inc.        5.375767
# 318         Skywest Airlines Inc.        4.193237
# 319        American Airlines Inc.       12.202115
# 320          Alaska Airlines Inc.        0.371166
# 321         Skywest Airlines Inc.        3.259159
#
#                 max_delay_airline
# 0           Skywest Airlines Inc.
# 1    American Eagle Airlines Inc.
# 2                 US Airways Inc.
# 3           Skywest Airlines Inc.
# 4     Atlantic Southeast Airlines
# ..                            ...
# 317          Alaska Airlines Inc.
# 318         Skywest Airlines Inc.
# 319  American Eagle Airlines Inc.
# 320          Alaska Airlines Inc.
# 321         Skywest Airlines Inc.
#
# [322 rows x 13 columns]

# %%
airport.dtypes
# Out:
# DESTINATION_AIRPORT             object
# AIRPORT                         object
# CITY                            object
# STATE                           object
# COUNTRY                         object
# LATITUDE                       float64
# LONGITUDE                      float64
# fraction of delayed_flights    float64
# Average delay time             float64
# min_delay_time                 float64
# mindelay_airline                object
# max_delay_time                 float64
# max_delay_airline               object
# dtype: object

# %%
# Plotting altair char of the delay times and fraction of delayed flights at different airports 

states = alt.topo_feature(data.us_10m.url, feature='states')
airports = data.airports()

background = alt.Chart(states).mark_geoshape(
    fill='white',
    stroke='black'
).project('albersUsa').properties(
    width=800,
    height=600
    #alt.txt('states')
)
scale = alt.Scale(
    domain=[0,flights_25, flights_median,flights_75, 0.65],
    range=[10, 160, 320, 640, 800],
    #range=[1, 160, 320,640, 1000],
    type='linear'
)

scale1 = alt.Scale(
    domain=[13,time_25,delaytime_median,time_75,max(airport.loc[:,'Average delay time'])],
    range=['blue','green', 'yellow','orange', 'red'],
    type='linear'
)
#alt.Scale(range=[1, 1000])
points = alt.Chart(airport).mark_circle().encode(
    longitude='LONGITUDE',
    latitude='LATITUDE',
    size=alt.Size('fraction of delayed_flights:Q',scale=scale),
    color=alt.Color('Average delay time', scale=scale1),
    tooltip=['fraction of delayed_flights','Average delay time','AIRPORT','mindelay_airline','min_delay_time:Q','max_delay_airline','max_delay_time:Q']
)

background + points
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # <font size =10> Visualization 4</font>

# %%
#Seperating cancelled flights data 

Cancelled=flight_data.loc[:,['AIRLINE','CANCELLED']].groupby('AIRLINE').mean()
Cancelled=Cancelled.round(3)

# %%
#Plotting cancelled flights data

import matplotlib.pyplot as plt
ax=Cancelled.plot(kind='barh',figsize=(10,10),title='Fraction of cancelled flights')
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ## <font size =10> Visualization 5</font>

# %%
delay_reason=flights.dropna(subset=['AIR_SYSTEM_DELAY','SECURITY_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY'],how='all')

# %%
delay_reason
# Out:
#          MONTH  DAY  DAY_OF_WEEK IATA_CODE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 37           1    1            4        AS            SLC                 SJC
# 52           1    1            4        AS            BUR                 SEA
# 57           1    1            4        AS            SAN                 OGG
# 63           1    1            4        AS            SEA                 SFO
# 65           1    1            4        AS            OAK                 OGG
# ...        ...  ...          ...       ...            ...                 ...
# 5713978     12   31            4        VX            LAX                 LAS
# 5713987     12   31            4        VX            LAX                 DAL
# 5713990     12   31            4        VX            DAL                 SFO
# 5713992     12   31            4        VX            DAL                 LAS
# 5713999     12   31            4        VX            LAS                 SFO
#
#          DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY  DIVERTED  AIR_SYSTEM_DELAY  \
# 37                  67.0       584           50.0         0               0.0
# 52                 124.0       937          120.0         0               0.0
# 57                  -4.0      2541           24.0         0              24.0
# 63                   8.0       679           26.0         0              18.0
# 65                  19.0      2349           29.0         0              10.0
# ...                  ...       ...            ...       ...               ...
# 5713978             83.0       236           82.0         0               0.0
# 5713987            111.0      1246           80.0         0               0.0
# 5713990             48.0      1476           42.0         0               0.0
# 5713992             29.0      1067           36.0         0               7.0
# 5713999             19.0       414           16.0         0               0.0
#
#          SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 37                  0.0            0.0                  0.0           50.0
# 52                  0.0            0.0                  0.0          120.0
# 57                  0.0            0.0                  0.0            0.0
# 63                  0.0            8.0                  0.0            0.0
# 65                  0.0           19.0                  0.0            0.0
# ...                 ...            ...                  ...            ...
# 5713978             0.0            0.0                 82.0            0.0
# 5713987             0.0            0.0                 80.0            0.0
# 5713990             0.0            0.0                 42.0            0.0
# 5713992             0.0            0.0                 29.0            0.0
# 5713999             0.0           16.0                  0.0            0.0
#
#                       AIRLINE  DELAY_OR_NOT
# 37       Alaska Airlines Inc.          True
# 52       Alaska Airlines Inc.          True
# 57       Alaska Airlines Inc.          True
# 63       Alaska Airlines Inc.          True
# 65       Alaska Airlines Inc.          True
# ...                       ...           ...
# 5713978        Virgin America          True
# 5713987        Virgin America          True
# 5713990        Virgin America          True
# 5713992        Virgin America          True
# 5713999        Virgin America          True
#
# [1063439 rows x 17 columns]

# %%
delayed_flights=delay_reason.loc[:,['AIRLINE','SECURITY_DELAY']].groupby('AIRLINE').count()
delayed_flights
# Out:
#                               SECURITY_DELAY
# AIRLINE
# Alaska Airlines Inc.                   22352
# American Airlines Inc.                130279
# American Eagle Airlines Inc.           60547
# Atlantic Southeast Airlines           109184
# Delta Air Lines Inc.                  118023
# Frontier Airlines Inc.                 23570
# Hawaiian Airlines Inc.                  8618
# JetBlue Airways                        59175
# Skywest Airlines Inc.                 107795
# Southwest Airlines Co.                236626
# Spirit Air Lines                       34221
# US Airways Inc.                        36549
# United Air Lines Inc.                 104722
# Virgin America                         11778

# %%
#Getting data of number of delayed flight because of given reason grouping with respect to different airlines.


delay_airlines=pd.DataFrame()
delay_airlines=delay_reason.loc[:,['AIRLINE','ARRIVAL_DELAY']].groupby('AIRLINE').count()
#delay_airlines.rename(column={'SECURITY_DELAY': 'DELAYS'})
list1=['AIR_SYSTEM_DELAY','SECURITY_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY']
for i in range(0,len(list1)):
    temp=delay_reason[delay_reason.loc[:,list1[i]]!=0]
    delayed_temp=temp.loc[:,['AIRLINE',list1[i]]].groupby('AIRLINE').count()
    delay_airlines=delay_airlines.merge(delayed_temp,on='AIRLINE')
delay_airlines
# Out:
#                               ARRIVAL_DELAY  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# AIRLINE
# Alaska Airlines Inc.                  22352             14897             250
# American Airlines Inc.               130279             70383             731
# American Eagle Airlines Inc.          60547             35806             308
# Delta Air Lines Inc.                 118023             64230              58
# Hawaiian Airlines Inc.                 8618               325              29
# JetBlue Airways                       59175             33913             433
# Skywest Airlines Inc.                107795             58509             345
# Southwest Airlines Co.               236626             97772             554
# Spirit Air Lines                      34221             28378             299
# US Airways Inc.                       36549             23708             372
# United Air Lines Inc.                104722             49858              26
# Virgin America                        11778              5395              79
#
#                               AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# AIRLINE
# Alaska Airlines Inc.                   8363                 7866
# American Airlines Inc.                68656                57590
# American Eagle Airlines Inc.          27236                32125
# Delta Air Lines Inc.                  63128                50112
# Hawaiian Airlines Inc.                 7395                 4877
# JetBlue Airways                       38665                31684
# Skywest Airlines Inc.                 39127                62432
# Southwest Airlines Co.               144524               163188
# Spirit Air Lines                      17307                11722
# US Airways Inc.                       19717                13654
# United Air Lines Inc.                 65999                49865
# Virgin America                         4445                 5396
#
#                               WEATHER_DELAY
# AIRLINE
# Alaska Airlines Inc.                    867
# American Airlines Inc.                 9967
# American Eagle Airlines Inc.           9105
# Delta Air Lines Inc.                  11838
# Hawaiian Airlines Inc.                  572
# JetBlue Airways                        2173
# Skywest Airlines Inc.                  4426
# Southwest Airlines Co.                10086
# Spirit Air Lines                        925
# US Airways Inc.                        1722
# United Air Lines Inc.                  7531
# Virgin America                         2072

# %%
#Plotting airlines data w.r.t delay reason for all the airlines

ax=delay_airlines.plot(kind='barh',figsize=(15,20),title='Number of delayed flights',ylabel='Number of flights delayed',width=0.75)
for container in ax.containers:
    #,width=1ax.setp(container, width=10)
    ax.bar_label(container)
